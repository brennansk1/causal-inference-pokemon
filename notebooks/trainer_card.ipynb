# %% [markdown]
# # Trainer Card — Progress TrackerTrack your progress through the Kanto causal inference adventure.

# %%
from IPython.display import HTML, displayimport datetime

# %% [markdown]
# ## Your Trainer Card

# %%
TRAINER_NAME = "Your Name Here"STARTER = "Charmander"  # or Bulbasaur / SquirtleBADGES = ["Boulder"]     # Add as you earn themall_badges = ["Boulder", "Cascade", "Thunder", "Rainbow", "Soul", "Marsh", "Volcano", "Earth"]badge_html = ""for b in all_badges:    earned = b in BADGES    color = "#FFD733" if earned else "#CCCCCC"    badge_html += f'<span style="display:inline-block;padding:8px 14px;margin:4px;border-radius:20px;background:{color};color:#333;font-weight:bold;">{b}{"" if earned else ""}</span>'html = f'''<div style="border:3px solid #EE1515;border-radius:12px;padding:22px;background:linear-gradient(135deg,#FFF8E1,#FFE082);font-family:sans-serif;max-width:640px;">  <h2 style="margin:0 0 8px 0;color:#EE1515;">TRAINER CARD</h2>  <table style="width:100%;border:none;">    <tr><td style="padding:6px;"><b>Name:</b></td><td>{TRAINER_NAME}</td></tr>    <tr><td style="padding:6px;"><b>Starter:</b></td><td>{STARTER}</td></tr>    <tr><td style="padding:6px;"><b>Badges:</b></td><td>{len(BADGES)}/8</td></tr>    <tr><td style="padding:6px;"><b>Registered:</b></td><td>{datetime.date.today()}</td></tr>  </table>  <div style="margin-top:14px;">{badge_html}</div></div>'''display(HTML(html))

# %% [markdown]
# ## Chapter Progress Checklist

# %%
chapters = [    ("Ch 1 — Pallet Town: Potential Outcomes", False),    ("Ch 2 — Pewter City: Randomized Experiments", False),    ("Ch 3 — Cerulean City: DAGs", False),    ("Ch 4 — Vermilion City: Matching", False),    ("Ch 5 — Celadon City: Regression/IPW/DR", False),    ("Ch 6 — Fuchsia & Cinnabar: IV & RDD", False),    ("Ch 7 — Saffron City: DiD & Synthetic Control", False),    ("Ch 8 — Indigo Plateau: Advanced Topics", False),]rows = ""for name, done in chapters:    mark = "[DONE]" if done else "[ ]"    color = "#4DAD5B" if done else "#999"    rows += f'<tr><td style="color:{color};padding:6px;"><b>{mark}</b></td><td style="padding:6px;">{name}</td></tr>'display(HTML(f'<table style="font-family:monospace;font-size:14px;">{rows}</table>'))

# %% [markdown]
# ## Skills Mastered

# %%
skills = [    "Potential Outcomes Framework",    "Randomization Inference",    "Directed Acyclic Graphs",    "Matching & Propensity Scores",    "Inverse Probability Weighting",    "Doubly Robust Estimation",    "Instrumental Variables",    "Regression Discontinuity",    "Difference-in-Differences",    "Synthetic Control",    "Causal Forests",    "Double Machine Learning",    "Mediation Analysis",    "Sensitivity Analysis",]print("Skills you can acquire in this textbook:")for i, s in enumerate(skills, 1):    print(f"  {i:2d}. {s}")

# %% [markdown]
# ## Certificate of CompletionDisplay this cell once you have finished all 8 chapters.

# %%
def display_certificate(name="Your Name"):    html = f'''    <div style="border:6px double #EE1515;padding:32px;background:#FFFEF7;text-align:center;font-family:serif;max-width:720px;">      <h1 style="color:#EE1515;margin:0;">Certificate of Completion</h1>      <p style="font-size:18px;margin-top:16px;">This certifies that</p>      <h2 style="color:#3B4CCA;margin:8px 0;">{name}</h2>      <p style="font-size:18px;">has successfully completed</p>      <h3 style="margin:8px 0;">Causal Inference: A Pokemon Approach</h3>      <p style="font-style:italic;">Kanto Region Edition</p>      <p style="margin-top:22px;font-size:16px;">        Earned all 8 gym badges and defeated the Champion.<br>        Mastery: Potential Outcomes &middot; DAGs &middot; Matching &middot; IV &middot; RDD &middot; DiD &middot; Causal Forests &middot; DML      </p>      <p style="margin-top:28px;color:#888;">{datetime.date.today()}</p>    </div>    '''    display(HTML(html))# Uncomment when you are ready:# display_certificate("Your Name Here")
